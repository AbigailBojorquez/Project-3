# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import pymysql
from sqlalchemy import create_engine
from sqlalchemy_utils import create_database, database_exists
pymysql.install_as_MySQLdb()

# %% [markdown]
# ### Part 1: Download several files from IMDB’s movie data set and filter out the subset of moves requested by the stakeholder.
#
# #### Title Basics:
# - Movie ID (tconst)
# - Primary Title
# - Start Year
# - Runtime (in Minutes)
# - Genres

# %%
# Load df from the csv 
basics_df = pd.read_csv('Data/title_basics.csv.gz')
basics_df.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0     2020.0      NaN
# 2                 The Other Side of the Wind        0     2018.0      NaN
# 3                          The Naked Monster        0     2005.0      NaN
# 4                       Crime and Punishment        0     2002.0      NaN
#
#    runtimeMinutes                  genres
# ...

# %%
basics_df['genres_split'] = basics_df['genres'].str.split(',')
basics_df
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# 3      tt0088751     movie                                  The Naked Monster
# 4      tt0096056     movie                               Crime and Punishment
# ...          ...       ...                                                ...
# 84576  tt9914942     movie                             Life Without Sara Amat
# 84577  tt9915872     movie                               The Last White Witch
# 84578  tt9916170     movie                                      The Rehearsal
# 84579  tt9916190     movie                                          Safeguard
# 84580  tt9916362     movie                                              Coven
#
# ...

# %%
exploded_genres = basics_df.explode('genres_split')
exploded_genres.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 0  tt0035423     movie                                     Kate & Leopold
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 0                             Kate & Leopold        0     2001.0      NaN
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0     2020.0      NaN
# 2                 The Other Side of the Wind        0     2018.0      NaN
#
#    runtimeMinutes                  genres genres_split
# ...

# %%
genres_split = basics_df['genres'].str.split(",")

unique_genres = genres_split.explode().unique()
unique_genres
# Out:
# array(['Comedy', 'Fantasy', 'Romance', 'Drama', 'Horror', 'Sci-Fi',
#        'Mystery', 'Musical', 'Action', 'Adventure', 'Crime', 'Thriller',
#        'Music', 'Animation', 'Family', 'History', 'War', 'Biography',
#        'Sport', 'Western', 'Adult', 'Short', 'Reality-TV', 'News',
#        'Talk-Show', 'Game-Show'], dtype=object)

# %%
unique_genres = sorted(exploded_genres['genres_split'].unique())

# %%
title_genres = exploded_genres[['tconst','genres_split']].copy()
title_genres.head()
# Out:
#       tconst genres_split
# 0  tt0035423       Comedy
# 0  tt0035423      Fantasy
# 0  tt0035423      Romance
# 1  tt0062336        Drama
# 2  tt0069049        Drama

# %%
## Make dictionary with list of unique genres as key, new int id as values
genre_id_map = dict(zip(unique_genres, range(len(unique_genres))))
genre_id_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Short': 20,
#  'Sport': 21,
#  'Talk-Show': 22,
#  'Thriller': 23,
#  'War': 24,
#  'Western': 25}

# %%
## make new integer genre_id and drop string genres
title_genres['genre_id'] = title_genres['genres_split'].map(genre_id_map)
title_genres = title_genres.drop(columns = 'genres_split')
title_genres.head()
# Out:
#       tconst  genre_id
# 0  tt0035423         5
# 0  tt0035423         9
# 0  tt0035423        18
# 1  tt0062336         7
# 2  tt0069049         7

# %%
# manually make df with named cols from .keys and .values
genre_lookup = pd.DataFrame({'genre_name': genre_id_map.keys(),
                            'genre_id': genre_id_map.values()})
genre_lookup.head()
# Out:
#   genre_name  genre_id
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %%
## loading mysql credentials
with open('/Users/AbigailBojorquez/.secret/mysql.json') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['username', 'password'])

# %%
## creating connection to database with sqlalchemy
from urllib.parse import quote_plus as urlquote
connection  = f"mysql+pymysql://{login['username']}:{urlquote(login['password'])}@localhost/movies"
engine = create_engine(connection)

# Check if the database exists. If not, create it.
if database_exists(connection) == False:
  create_database(connection)
else:
  print('The database already exists')
# Out:
# The database already exists

# %%
basics_df = basics_df.drop(columns = ['originalTitle', 'isAdult', 'titleType', 'genres','genres_split'])
basics_df.head()
# Out:
#       tconst                                       primaryTitle  startYear  \
# 0  tt0035423                                     Kate & Leopold     2001.0
# 1  tt0062336  The Tango of the Widower and Its Distorting Mi...     2020.0
# 2  tt0069049                         The Other Side of the Wind     2018.0
# 3  tt0088751                                  The Naked Monster     2005.0
# 4  tt0096056                               Crime and Punishment     2002.0
#
#    endYear  runtimeMinutes
# 0      NaN             118
# 1      NaN              70
# 2      NaN             122
# 3      NaN             100
# 4      NaN             126

# %%
## Example
from sqlalchemy.types import *
## Calculate max string lengths for object columns
key_len = basics_df['tconst'].fillna('').map(len).max()
title_len = basics_df['primaryTitle'].fillna('').map(len).max()
## Create a schema dictonary using Sqlalchemy datatype objects
df_schema = {
    "tconst": String(key_len+1), 
    "primaryTitle": Text(title_len+1),
    'startYear':Float(),
    'endYear':Float(),
    'runtimeMinutes':Integer()}

# %%
# Save to sql with dtype and index=False
basics_df.to_sql('title_basics',engine,dtype=df_schema,if_exists='replace',index=False)
# Out:
# 84581

# %%
engine.execute('ALTER TABLE title_basics ADD PRIMARY KEY (`tconst`);')

# %%
title_genres.to_sql('title_genres',engine, if_exists='replace',index=False)
# Out:
# 158032

# %%
genre_lookup.to_sql('genre_lookup',engine, if_exists='replace',index=False)
# Out:
# 26

# %%
engine.execute('ALTER TABLE genre_lookup ADD PRIMARY KEY (`genre_id`);')

# %%
q = """
SELECT * FROM title_basics
LIMIT 5;"""
pd.read_sql(q, engine)
# Out:
#       tconst                                       primaryTitle  startYear  \
# 0  tt0035423                                     Kate & Leopold     2001.0
# 1  tt0062336  The Tango of the Widower and Its Distorting Mi...     2020.0
# 2  tt0069049                         The Other Side of the Wind     2018.0
# 3  tt0088751                                  The Naked Monster     2005.0
# 4  tt0096056                               Crime and Punishment     2002.0
#
#   endYear  runtimeMinutes
# 0    None             118
# 1    None              70
# 2    None             122
# 3    None             100
# 4    None             126

# %%
q = """
SELECT * FROM title_genres
LIMIT 5;"""
pd.read_sql(q, engine)
# Out:
#       tconst  genre_id
# 0  tt0035423         5
# 1  tt0035423         9
# 2  tt0035423        18
# 3  tt0062336         7
# 4  tt0069049         7

# %%
q = """
SELECT * FROM genre_lookup
LIMIT 5;"""
pd.read_sql(q, engine)
# Out:
#   genre_name  genre_id
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %% [markdown]
# #### Title Ratings
# - Movie ID (tconst)
# - Average Movie Rating
# - Number of Votes

# %%
#Load df from the csv
title_ratings_df = pd.read_csv('Data/title_ratings.csv.gz')
title_ratings_df.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1936
# 1  tt0000002            5.8       262
# 2  tt0000005            6.2      2570
# 3  tt0000006            5.1       177
# 4  tt0000007            5.4       808

# %%
key_len = title_ratings_df['tconst'].fillna('').map(len).max()

#Create a schema dic
ratings_schema = {
    "tconst": String(title_ratings_df['tconst'].str.len().max()), 
    'averageRating':Float(),
    'numVotes':Integer()}

# %%
#Save the dataframe to an sql table
title_ratings_df.to_sql('title_ratings',
              engine, 
              dtype=df_schema,
              if_exists='replace',
              index=False)
# Out:
# 484321

# %%
engine.execute('ALTER TABLE title_ratings ADD PRIMARY KEY (`tconst`);')

# %%
q = """
SELECT * FROM title_ratings 
LIMIT 5
; """
pd.read_sql(q, engine)
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1936
# 1  tt0000002            5.8       262
# 2  tt0000005            6.2      2570
# 3  tt0000006            5.1       177
# 4  tt0000007            5.4       808

# %% [markdown]
# #### The TMDB API Results (multiple files)
# - Movie ID
# - Revenue
# - Budget
# - Certification (MPAA Rating)

# %%
#Load the dataframe from the csv file
tmdb_data = pd.read_csv('Data/tmdb_results_combined.csv.gz')
tmdb_data.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0035423    0.0  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg                   NaN
# 2  tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg                   NaN
# 3  tt0118652    0.0  /mWxJEFRMvkG4UItYJkRDMgWQ08Y.jpg                   NaN
# 4  tt0119004    0.0  /7xrlSPGDO4CDT6IHTctDlkYxTzw.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  48000000.0  [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...      NaN
# 2  22000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN
# 3   1000000.0  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...      NaN
# 4         0.0                      [{'id': 18, 'name': 'Drama'}]      NaN
#
# ...

# %%
#Drop irrelevant columns
tmdb_data = tmdb_data.loc[:,["imdb_id","revenue",'budget','certification']]
tmdb_data.drop(0, inplace=True, axis=0)

#Display the first 5 rows
tmdb_data.head()
# Out:
#      imdb_id     revenue      budget certification
# 1  tt0035423  76019048.0  48000000.0         PG-13
# 2  tt0118589   5271666.0  22000000.0         PG-13
# 3  tt0118652         0.0   1000000.0             R
# 4  tt0119004      6297.0         0.0           NaN
# 5  tt0120681  74558115.0  35000000.0             R

# %%
#Create a schema dictonary using datatype objects
df_schema = {
    'imdb_id': String(tmdb_data['imdb_id'].str.len().max()), 
    'budget':Float(),
    'revenue':Float(),
    'certification': String(tmdb_data['certification'].str.len().max())}

#Save the dataframe to an sql table
tmdb_data.to_sql('tmdb_data',
              engine, 
              dtype=df_schema,
              if_exists='replace',
              index=False)
# Out:
# 625

# %%
#Use the engine to update title_basics with a primary key
engine.execute('ALTER TABLE tmdb_data ADD PRIMARY KEY (`imdb_id`);')

# %%
#Display the first 5 rows of the table using an SQL query
q = """
SELECT * 
FROM tmdb_data LIMIT 5
;"""

pd.read_sql(q, engine)
# Out:
#      imdb_id     revenue      budget certification
# 0  tt0035423  76019000.0  48000000.0         PG-13
# 1  tt0113026         0.0  10000000.0          None
# 2  tt0118589   5271670.0  22000000.0         PG-13
# 3  tt0118652         0.0   1000000.0             R
# 4  tt0118694  12855000.0    150000.0            PG

# %%
q = """SHOW TABLES"""
pd.read_sql(q, engine)
# Out:
#   Tables_in_movies
# 0     genre_lookup
# 1     title_basics
# 2     title_genres
# 3    title_ratings
# 4        tmdb_data
